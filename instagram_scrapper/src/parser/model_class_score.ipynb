# %%
import my_utils
from my_utils.my_utils import create_generator

# %%
import importlib
importlib.reload(my_utils)

from PIL import Image

# %%
counter = 0
for X,Y_score in create_generator(output="scores"):
    counter +=1
    if counter == 1:
        break

# %%
counter = 0
for X,Y_label in create_generator(output="labels"):
    counter +=1
    if counter == 1:
        break

# %%
Image.fromarray((X[6]*255).astype("uint8"))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F7692DFD4E0>

# %%
Y_label[6]
# Out:
# 3.4856317298358883

# %%
Y_score[6]
# Out:
# 10.0
